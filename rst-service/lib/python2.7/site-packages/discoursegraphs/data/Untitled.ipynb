# %%
import discoursegraphs as dg

# %%
dis_dg = dg.read_dis('rst-example1.dis')

# %%
dis_dg.dis_tree
# Out:
# ParentedTree('Root', [ParentedTree('span', ['1', '7']), ParentedTree('Nucleus', [ParentedTree('span', ['1', '4']), ParentedTree('rel2par', ['span']), ParentedTree('Nucleus', [ParentedTree('span', ['1', '3']), ParentedTree('rel2par', ['span']), ParentedTree('Satellite', [ParentedTree('leaf', ['1']), ParentedTree('rel2par', ['attribution']), ParentedTree('text', ['_!blah', 'blah', 'blah_!'])]), ParentedTree('Nucleus', [ParentedTree('span', ['2', '3']), ParentedTree('rel2par', ['span']), ParentedTree('Nucleus', [ParentedTree('leaf', ['2']), ParentedTree('rel2par', ['span']), ParentedTree('text', ['_!blah', 'blah', 'blah_!'])]), ParentedTree('Satellite', [ParentedTree('leaf', ['3']), ParentedTree('rel2par', ['consequence-n']), ParentedTree('text', ['_!blah', 'blah', 'blah_!'])])])]), ParentedTree('Satellite', [ParentedTree('leaf', ['4']), ParentedTree('rel2par', ['elaboration-additional']), ParentedTree('text', ['_!blah', 'blah', 'blah_!'])])]), ParentedTree('Satellite', [ParentedTree('s
# ...

# %%
dg.readwrite.rst.rs3.
